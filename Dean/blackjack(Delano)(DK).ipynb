# %% [markdown]
# # BlackJack
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import requests
import json

# %%
file_to_load = "//Users//deankleto//Desktop//Project_1//blkjckhands.csv"

# Read Purchasing File and store into Pandas data frame
BlackJack = pd.read_csv(file_to_load)
df=pd.DataFrame(BlackJack)
delup_df=df[["ply2cardsum","dealcard2","winloss"]]
delup_df=delup_df.rename(columns={"ply2cardsum": "DealTotal",
                                 "dealcard1": "DealerDwn",
                                 "dealcard2": "DealerUp",
                                 "winloss": "WinLoss"})

delup_df.head()
# Out:
#    DealTotal  DealerUp WinLoss
# 0         17         8    Loss
# 1         19         8     Win
# 2         17         8    Loss
# 3         12         8    Loss
# 4         12         8    Loss

# %%
delup_df.groupby("WinLoss")
delup_df.max()
# Out:
# DealTotal     21
# DealerUp      11
# WinLoss      Win
# dtype: object

# %%
pd.pivot_table(delup_df,index=["DealTotal"]
               ,columns=["WinLoss"]
               ,values=["WinLoss"]
               ,aggfunc=['size']
               ,fill_value = 0)
# Out:
#             size
# WinLoss     Loss   Push    Win
# DealTotal
# 2            984     91    524
# 3           2609    201   1241
# 4           6320    521   3336
# 5          10350    970   5327
# 6          13808   1388   7123
# 7          16564   2754   9422
# 8          13566   2646  10258
# 9          14628   3235  14074
# 10         14435   4306  18633
# 11         15616   4258  23148
# 12         52146   4795  27003
# 13         51255   4105  25467
# 14         48064   3690  23379
# 15         44859   3251  20860
# 16         40990   2887  18519
# 17         31176   8105  17175
# 18         25355   8071  25193
# 19         15794   7026  30338
# 20         11302  16857  66941
# 21             0   5076  37985

# %%
delup7 = delup_df[delup_df.DealerUp == 7]
delup7.head()
# Out:
#     DealTotal  DealerUp WinLoss
# 24         13         7    Loss
# 25         17         7    Loss
# 26         20         7     Win
# 27         11         7    Push
# 28         16         7    Loss

# %%
pd.pivot_table(delup7,index=["DealTotal"]
               ,columns=["WinLoss"]
               ,values=["WinLoss"]
               ,aggfunc=['size']
               ,fill_value = 0)
# Out:
#            size
# WinLoss    Loss  Push   Win
# DealTotal
# 2            80     7    46
# 3           199    10   109
# 4           450    33   294
# 5           717    79   478
# 6           974   113   617
# 7          1039   367   842
# 8           822   216   982
# 9           824   243  1347
# 10          919   261  1682
# 11         1028   280  2051
# 12         3533   380  2468
# 13         3616   309  2200
# 14         3451   286  2012
# 15         3165   228  1813
# 16         2913   224  1598
# 17         1488  1462  1260
# 18         1055   605  2879
# 19          621   325  3137
# 20          518   626  6185
# 21            0   237  3129

# %%
delup7.plot.line()
plt.
plt.ylim(0, 80000)
plt.xlim(0, 25)
plt.grid()
plt.show()

# %%
stats = delup7.keys()

x_axis =

# %%
delup_ace = delup_df[delup_df.DealerUp == 11]
delup_ace.head()
# Out:
#     DealTotal  DealerUp WinLoss
# 66         19        11    Loss
# 67         18        11    Loss
# 68         14        11    Loss
# 69         19        11    Loss
# 70         21        11    Push

# %%
columns=""

delup_ace = pd.DataFrame([
    ['19', 'DealTotal', '11'],
    ['18', 'DealTotal', '11'],
] columns=['DealerUp', 'DealTotal', 'WinLoss'])

delup_ace = delup_ace.pivot(index='DealTotal', columns='DealerUp', values='WinLoss')
delup_ace.plot()
# Out:
#   File "<ipython-input-23-16741e8ecd0d>", line 6
#     ] columns=['DealerUp', 'DealTotal', 'WinLoss'])
#             ^
# SyntaxError: invalid syntax
